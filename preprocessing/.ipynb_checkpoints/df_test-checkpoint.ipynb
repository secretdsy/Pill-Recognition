# %%
import pandas as pd
import os
import urllib
import pdb
import cv2
import numpy as np

# %%
shape_label = {'삼각형': 0, '사각형': 1, '오각형': 2, '육각형': 3, '팔각형': 4, 
               '원형': 5, '반원형': 6, '타원형': 7, '장방형': 8, '마름모형': 9, '기타': 10}
shape_label
# Out:
# {'기타': 10,
#  '마름모형': 9,
#  '반원형': 6,
#  '사각형': 1,
#  '삼각형': 0,
#  '오각형': 2,
#  '원형': 5,
#  '육각형': 3,
#  '장방형': 8,
#  '타원형': 7,
#  '팔각형': 4}

# %%
label_path = './label/label_shape.xls'
xls = pd.read_excel(label_path)
df = pd.DataFrame(xls)
# print(df1)

df2 = df[df.columns[-1]].map(shape_label)
df2 = pd.DataFrame(df2)
df['shape'] = df2['shape']
# df['shape'].astype(str)
# df['No'].astype(str)
print(df)
# Out:
#               No  shape
# 0      197400571      5
# 1      198803039      8
# 2      200703756      5
# 3      199703153      8
# 4      200004062      5
# 5      200402488      5
# 6      199102043      8
# 7      199702297      5
# 8      200502773      7
# 9      199502505      8
# 10     200300408      8
# 11     199700745      8
# 12     200300405      7
# 13     198701796      8
# 14     200202791      5
# 15     200700055      5
# 16     198100119      5
# 17     198700405      8
# 18     198200170      8
# 19     200300401      8
# 20     200200444      7
# 21     200400462      8
# 22     200400486      7
# 23     200400475      8
# 24     198100123      8
# 25     200500547      7
# 26     199400494      5
# 27     200200445      5
# 28     199700749      5
# 29     200500548      7
# ...          ...    ...
# 21084  201804334      5
# 21085  201804348      8
# 21086  201803560      5
# 21087  201804952      5
# 21088  201804850      5
# 21089  201804185      5
# ...

# %%
df.columns
# Out:
# Index(['No', 'shape'], dtype='object')

# %%
df2 = pd.DataFrame(columns=['No','shape'])
df3 = pd.DataFrame(columns=['No','shape'])

# %%
img_list = ['197700114.jpg', '197700085.jpg', '197700142.jpg', '197700117.jpg', '197700192.jpg', '197700137.jpg', '197700088.jpg', '197700171.jpg', '197700126.jpg', '197700120.jpg', '195900001.jpg', '196200002.jpg', '195900043.jpg', '196200034.jpg', '196000003.jpg', '195900032.jpg', '196300043.jpg', '196000011.jpg', '196000001.jpg', '196000008.jpg', '196200032.jpg', '196300001.jpg', '196300019.jpg', '196700049.jpg', '196200043.jpg', '196200046.jpg', '196400037.jpg', '196400046.jpg', '196400005.jpg', '196300064.jpg', '196400082.jpg', '196800048.jpg', '196800078.jpg', '196400099.jpg', '196600011.jpg', '196500004.jpg', '196600007.jpg', '196700060.jpg', '196600012.jpg', '196900043.jpg', '197000049.jpg', '197000068.jpg', '197000005.jpg', '197000079.jpg', '197000050.jpg', '197100057.jpg', '197000053.jpg', '196900101.jpg', '197000076.jpg', '197000212.jpg', '197000037.jpg', '197000215.jpg', '197000040.jpg', '197100073.jpg', '197000208.jpg', '197100165.jpg', '197000102.jpg', '197000196.jpg', '197100015.jpg', '197200016.jpg', '197000211.jpg', '197100081.jpg', '197000104.jpg', '197100097.jpg', '197100088.jpg', '197200025.jpg', '197200092.jpg', '197200226.jpg', '197200084.jpg', '197200091.jpg', '197200376.jpg', '197200160.jpg', '197300021.jpg', '197300128.jpg', '197300084.jpg', '197300013.jpg', '197200171.jpg', '197300104.jpg', '197200484.jpg', '197400059.jpg', '197400028.jpg', '197300155.jpg', '197400039.jpg', '197400033.jpg', '197300172.jpg', '197400186.jpg', '197300151.jpg', '197300135.jpg', '197400040.jpg', '197300096.jpg', '197400397.jpg', '197400273.jpg', '197400347.jpg', '197400277.jpg', '197400246.jpg', '197400571.jpg', '197400278.jpg', '197400262.jpg', '197400343.jpg', '197400345.jpg', '197500140.jpg', '197400577.jpg', '197500016.jpg', '197500097.jpg', '197500088.jpg', '197500135.jpg', '197500004.jpg', '197500015.jpg', '197500098.jpg', '197500186.jpg', '197500007.jpg', '197500185.jpg', '197500274.jpg', '197500336.jpg', '197500285.jpg', '197500236.jpg', '197500272.jpg', '197500541.jpg', '197500234.jpg', '197500188.jpg', '197500299.jpg', '197500248.jpg', '197500338.jpg', '197500346.jpg', '197600035.jpg', '197600329.jpg', '197500450.jpg', '197500578.jpg', '197500463.jpg', '197600345.jpg', '197500580.jpg', '197600065.jpg', '197600036.jpg', '197500654.jpg', '197600046.jpg', '197600444.jpg', '197600432.jpg', '197600554.jpg', '197600612.jpg', '197600141.jpg', '197600539.jpg', '197700049.jpg', '197700008.jpg', '197600412.jpg', '197600483.jpg', '197700025.jpg', '197600550.jpg', '197700036.jpg', '197700028.jpg', '197600739.jpg']

# %%
for i in range(len(img_list)):
    df3 = df.loc[df['No'] == int(img_list[i].split('.')[0])]
    df2 = df2.append(df3, ignore_index=True)

# %%
for i in range(len(df2)):
    df2['shape'][i] = str(df2['shape'][i])
    df2['No'][i] = str(df2['No'][i]) + '.jpg'

# %%
df2.to_csv('./test_shape.csv', mode='w')

# %%
type(df2['No'][0])
# Out:
# str

# %%
# prediction 하고나서 다른 값들만 모아보기

LABEL_PATH = './label'
df = pd.read_csv(os.path.join(LABEL_PATH,'shape_VGG16.csv'))
shape_list = df['shape'].tolist()
pre_list = df['prediction'].tolist()
result = []
for i in range(len(shape_list)):
    if (shape_list[i] != pre_list[i]):
        result.append(i)
print(result)
df2 = pd.DataFrame(columns=['No','shape','prediction'])
for i in range(len(result)):
    df3 = df.loc[df['Unnamed: 0'] == result[i]]
    df2 = df2.append(df3)

df2.to_csv('./pre_shape.csv', mode='w')

# %%
label_path = './label/label_shape.xls'
xls = pd.read_excel(label_path)
df = pd.DataFrame(xls)
df
# Out:
#               No shape
# 0      197400571    원형
# 1      198803039   장방형
# 2      200703756    원형
# 3      199703153   장방형
# 4      200004062    원형
# 5      200402488    원형
# 6      199102043   장방형
# 7      199702297    원형
# 8      200502773   타원형
# 9      199502505   장방형
# 10     200300408   장방형
# 11     199700745   장방형
# 12     200300405   타원형
# 13     198701796   장방형
# 14     200202791    원형
# 15     200700055    원형
# 16     198100119    원형
# 17     198700405   장방형
# 18     198200170   장방형
# 19     200300401   장방형
# 20     200200444   타원형
# 21     200400462   장방형
# 22     200400486   타원형
# 23     200400475   장방형
# 24     198100123   장방형
# 25     200500547   타원형
# 26     199400494    원형
# 27     200200445    원형
# 28     199700749    원형
# 29     200500548   타원형
# ...          ...   ...
# 21084  201804334    원형
# 21085  201804348   장방형
# 21086  201803560    원형
# 21087  201804952    원형
# 21088  201804850    원형
# 21089  201804185    원형
# 21090  201804849    원형
# 21091  201804347    원형
# ...

# %%
label_path = './label/label_color.xls'
xls = pd.read_excel(label_path)
df = pd.DataFrame(xls)
df
# Out:
#               No color_front
# 0      197400571          노랑
# 1      198803039          갈색
# 2      200703756          분홍
# 3      199703153          하양
# 4      200004062          하양
# 5      200402488          하양
# 6      199102043          초록
# 7      199702297          하양
# 8      200502773          하양
# 9      199502505          초록
# 10     200300408          노랑
# 11     199700745          연두
# 12     200300405          자주
# 13     198701796          파랑
# 14     200202791          하양
# 15     200700055          하양
# 16     198100119          하양
# 17     198700405          연두
# 18     198200170          하양
# 19     200300401          하양
# 20     200200444          주황
# 21     200400462          갈색
# 22     200400486          주황
# 23     200400475          파랑
# 24     198100123          초록
# 25     200500547          하양
# 26     199400494          하양
# 27     200200445          연두
# 28     199700749          연두
# 29     200500548          주황
# ...          ...         ...
# ...

# %%
label_path = './label/color.csv'
csv = pd.read_csv(label_path)
df = pd.DataFrame(csv)
df
# Out:
#        Unnamed: 0  index             No  color_front
# 0               0      0  197400571.jpg          2.0
# 1               1      1  198803039.jpg         11.0
# 2               2      2  200703756.jpg          9.0
# 3               3      3  199703153.jpg         14.0
# 4               4      4  200004062.jpg         14.0
# 5               5      5  200402488.jpg         14.0
# 6               6      6  199102043.jpg          4.0
# 7               7      7  199702297.jpg         14.0
# 8               8      8  200502773.jpg         14.0
# 9               9      9  199502505.jpg          4.0
# 10             10     10  200300408.jpg          2.0
# 11             11     11  199700745.jpg          3.0
# 12             12     12  200300405.jpg         10.0
# 13             13     13  198701796.jpg          6.0
# 14             14     14  200202791.jpg         14.0
# 15             15     15  200700055.jpg         14.0
# 16             16     16  198100119.jpg         14.0
# ...

# %%
for i in range(len(df)):
    df['color_front'][i] = df['color_front'][i].astype(int)
    if i % 100 == 0:
        print(i)
# Out:
# C:\Users\secre\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# ...

# %%
label_path = './label/shape.csv'
csv = pd.read_csv(label_path)
df2 = pd.DataFrame(csv)
df2
# Out:
#        Unnamed: 0  index             No  shape
# 0               0      0  197400571.jpg      5
# 1               1      1  198803039.jpg      8
# 2               2      2  200703756.jpg      5
# 3               3      3  199703153.jpg      8
# 4               4      4  200004062.jpg      5
# 5               5      5  200402488.jpg      5
# 6               6      6  199102043.jpg      8
# 7               7      7  199702297.jpg      5
# 8               8      8  200502773.jpg      7
# 9               9      9  199502505.jpg      8
# 10             10     10  200300408.jpg      8
# 11             11     11  199700745.jpg      8
# 12             12     12  200300405.jpg      7
# 13             13     13  198701796.jpg      8
# 14             14     14  200202791.jpg      5
# 15             15     15  200700055.jpg      5
# 16             16     16  198100119.jpg      5
# 17             17     17  198700405.jpg      8
# 18             18     18  198200170.jpg      8
# ...

# %%
df3 = df2['shape']

# %%
df['shape'] = df2['shape']

# %%
type(df['shape'][1])
# Out:
# numpy.int64

# %%
df.to_csv('./label/shape_color_prediction.csv', mode='w')

# %%
LABEL_PATH = './label'
df = pd.read_csv(os.path.join(LABEL_PATH,'shape_color_prediction.csv'))

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  index             No  color_front  shape  \
# 0           0             0      0  197400571.jpg            2      5
# 1           1             1      1  198803039.jpg           11      8
# 2           2             2      2  200703756.jpg            9      5
# 3           3             3      3  199703153.jpg           14      8
# 4           4             4      4  200004062.jpg           14      5
#
#    color_prediction  shape_prediction
# 0                 2                 5
# 1                11                 8
# 2                 9                 5
# 3                14                 8
# 4                14                 5

# %%
color = df['color_front'][1] == df['color_prediction'][1]
# Out:
# True

# %%
count = 0
result = 0
for i in range(len(df)):
#     color = df['color_front'][i] == df['color_prediction'][i]
#     shape = df['shape'][i] == df['shape_prediction']
    if (df['color_front'][i] == df['color_prediction'][i]) and (df['shape'][i] == df['shape_prediction'][i]):
        count += 1
result = count / len(df)        
print('shape, color 둘 다 정답인 경우:', count)
print('전체 데이터 크기:', len(df))
print('결과:', result)
# Out:
# shape, color 둘 다 정답인 경우: 18363
# 전체 데이터 크기: 20959
# 결과: 0.8761391287752278

# %%
LABEL_PATH = './label'
df = pd.read_csv(os.path.join(LABEL_PATH,'shape_color_prediction.csv'))

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-1ee9bb651056> in <module>
# ----> 1 df['color_top3'][1].astype(int)
#
# AttributeError: 'str' object has no attribute 'astype'
